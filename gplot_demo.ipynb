# %% [markdown]
# # Using gnuplot via gplot.py in Jupyter

# %% [markdown]
# Importing and creation of a gnuplot instance for Jupyter.

# %%
from gplot import Iplot
iplot = Iplot()

# %% [markdown]
# ### Plot a gnuplot function
# Plot commands are executed by calling the instance.

# %%
iplot('sin(x)')

# %% [markdown]
# ### Plot data array
# Data array or lists can be also passed in the plot call. Note the extra comma after "pt 7".

# %%
import numpy as np
x = np.arange(100.)
y = np.sin(0.1*x) + 0.1*np.random.randn(100)

iplot(x**2, y, 'pt 7,', [5000], [0.4], 'lt 3 pt 5 ps 2 t "a big point"')

# %% [markdown]
# ### Plot a data file
# Data files and unix pipes are possible as well and need extra quotes.

# %%
iplot('"< seq 10" us 1:(log($1)):(0.5):1 w e pt 7 palette t ""')

# %% [markdown]
# ### 2D plots
# splot (and plot) are class methods.

# %%
iplot.splot('[-4:4][-4:4] (sin(x)/x*sin(y)/y)**2')

# %% [markdown]
# ### Available gnuplot styles

# %%
iplot.test()

# %% [markdown]
# The output before were png files which can be download with a right click. There is also svg and html/js/canvas; this is experimental and needs gnuplot.js.

# %%
iplot = Iplot(suffix='html')
iplot.grid()("sin(x), cos(x), atan(x)*1.5,", [1,2,3,4,3,2,1], 'w lp')
# Out:
#          <link rel="stylesheet" href="gp/gnuplot_mouse.css" type="text/css">
# <style>
#    img.icon-image {
#       max-width: None !important;
#    }
#    td.icon, td.mb0, td.mb1 {
#       background-color: #f7f7f7;
#       line-height: 16px;
#    }
# </style>
# <script src="canvastext.js"></script>
# <script src="gnuplot_common.js"></script>
# <script src="gnuplot_mouse.js"></script>
# <script type="text/javascript">
#    // to get correct mouse coords (overflow:auto, scrollTop)
#    document.getElementById("site").style.position = "sticky";
# </script>
# <script type="text/javascript">
#    // from view-source:http://gnuplot.sourceforge.net/demo_canvas/simple.html
#    var canvas, ctx;
#    gnuplot.grid_lines = true;
#    gnuplot.zoomed = false;
#    gnuplot.active_plot_name = "gnuplot_canvas";
#    gnuplot.active_plot = gnuplot.dummyplot;
#    gnuplot.help_URL = "http://gnuplot.sourceforge.net/demo_canvas_5.0/canvas_help.html";
#    gnuplot.dummyplot = function() {};
# ...

# %%
iplot = Iplot(suffix='svg')
iplot.grid()("sin(x), cos(x), atan(x)*1.5,", [1,2,3,4,3,2,1], 'w lp')
# Out:
#     Inline SVG1
#      <script>
# /*
#  * $Id: gnuplot_svg.js,v 1.8 2011/11/22 22:35:32 sfeam Exp $
#  */
# // Javascript routines for interaction with SVG documents produced by
# // gnuplot's SVG terminal driver.
#
# var gnuplot_svg = { };
#
# gnuplot_svg.version = "22 November 2011";
#
# gnuplot_svg.SVGDoc = null;
# gnuplot_svg.SVGRoot = null;
#
# gnuplot_svg.Init = function(e)
# {
#    gnuplot_svg.SVGDoc = e.target.ownerDocument;
#     console.log(gnuplot_svg.SVGDoc,e);
#    gnuplot_svg.SVGRoot = gnuplot_svg.SVGDoc.getElementsByTagName("svg")[0];
#    gnuplot_svg.axisdat = new Date();
# }
#
# gnuplot_svg.toggleVisibility = function(evt, targetId)
# {
#    var newTarget = evt.target;
#    if (targetId)
#       newTarget = gnuplot_svg.SVGDoc.getElementById(targetId);
#
#    var newValue = newTarget.getAttributeNS(null, 'visibility')
#
#    if ('hidden' != newValue)
#       newValue = 'hidden';
#    else
#       newValue = 'visible';
#
# ...

# %% [markdown]
# For gnuplot 5+, hypertext is available in svg and html.

# %%
iplot.version
# Out:
# 4.6
